# %% [markdown]
# # 标量

# %%
import numpy as np

# %%
# 整数
a = 4
a
# Out:
# 4

# %%
# 小数
b = 5.2
b
# Out:
# 5.2

# %%
# 负数
x = -1.3
x
# Out:
# -1.3

# %%
# 常数
p = np.pi
p
# Out:
# 3.141592653589793

# %%
# 无穷大
y = np.inf
y
# Out:
# inf

# %%
# 字母
z = 'M'
z
# Out:
# 'M'

# %%
# 非数
n = np.nan
n
# Out:
# nan

# %%
# 布尔值
3 == 4
# Out:
# False
